# %%
#Formulating title: # to bold, ## to make it heading 2, etc

# %% [markdown]
# # Introduction

# %% [markdown]
# #### Data analysis using python

# %%
"""
include tripple quotes for more than one line comment
"""
# Out:
# '\ninclude tripple quotes for more than one line comment\n'

# %%
#importing library

import pandas as pd  #used to import dataframes and simple manipulations  
import numpy as np # used for performing calculations/computations
import seaborn as sns # used for visualizations of data
import matplotlib.pyplot as plt # used for creation of  any kind of graphics

# %% [markdown]
# Importing the dataframe

# %%
df=pd.read_csv("C:/Users/Smuhoza/Documents/PYTHON TUTORIAL/car price data.csv") # importing csv file
# or you can add another slash to the default ones
#df=pd.read_csv(C:\\Users\\DMUCYO\\Desktop\\NISR Trainings\\Python\\car price data.csv")

df.head(5) # returns first 5 rows
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
#  _________________________________________________________________________________________________________________________

# %%
auto=pd.read_stata("C:\\Users\\Smuhoza\\Documents\PYTHON TUTORIAL\\cs_s1_s2_s3_s4_s6a_s6e_s6f_person.dta") #importing stata file
pd.set_option('display.max_columns', None) #to display all columns
auto.head(1)
# Out:
#        hhid     province    district ur2012 ur2_2012       region     weight  \
# 0  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
#
#                                              hhtype  s0q19m  s0q19y  \
# 0  Replaced different household (dependent code 95)    11.0    13.0
#
#        pop_wt    clust      rwanda surveyh quintile  poverty   Consumption  \
# 0  214.379379  10001.0  All Rwanda   Panel       Q4      3.0  305390.90625
#
#           pid    s1q1                 s1q2 s1q3y  s1q3m       s1q4     s1q5  \
# 0  10000101.0  Female  Household head (HH)  33.0    NaN  Separated  Kamonyi
#
#        s1q6 s1q7 s1q8 s1q9 s1q10 s1q11 s1q12 s1q13 s1q14 s1q15        s2q1  \
# 0  Rwandese   No  NaN  NaN   NaN   Yes   NaN   NaN   NaN   Yes  10000101.0
#
#   s2q2 s2q3y s2q3m     s2q4         s2q5  s2q6        s2q7   s2q8        s3q1  \
# 0   No  18.0   0.0  Kamonyi  Countryside  15.0  Employment  Alone  10000101.0
#
# ...

# %% [markdown]
# Renaming the variables

# %%
auto_new=auto.copy()  # copy copies the stated dataset

# %%
auto_new.rename(columns={
    "s1q1":"Gender",
    "s1q2":"Relationship_HHead",
    "s1q3y":"Age"   
},inplace=True) # to rename variables inside the dataset

# %%
#Selecting variables of interest
df=auto_new.loc[:,['hhid','province','ur2_2012','quintile','Consumption','poverty','Gender','Relationship_HHead','Age']]

# %%
df.shape # to display the dimension of dataset
df.head()
# Out:
#        hhid     province ur2_2012 quintile   Consumption  poverty  Gender  \
# 0  100001.0  Kigali City    Urban       Q4  305390.90625      3.0  Female
# 1  100001.0  Kigali City    Urban       Q4  305390.90625      3.0    Male
# 2  100001.0  Kigali City    Urban       Q4  305390.90625      3.0    Male
# 3  100001.0  Kigali City    Urban       Q4  305390.90625      3.0  Female
# 4  100001.0  Kigali City    Urban       Q4  305390.90625      3.0    Male
#
#         Relationship_HHead   Age
# 0      Household head (HH)  33.0
# 1    Son or daughter of HH  16.0
# 2    Son or daughter of HH  14.0
# 3    Son or daughter of HH  10.0
# 4  Brother or sister of HH  19.0

# %%
df.shape
# Out:
# (66081, 9)

# %%
df.info        # checking the nature
# Out:
# <bound method DataFrame.info of            hhid          province ur2_2012 quintile    Consumption  poverty  \
# 0      100001.0       Kigali City    Urban       Q4  305390.906250      3.0
# 1      100001.0       Kigali City    Urban       Q4  305390.906250      3.0
# 2      100001.0       Kigali City    Urban       Q4  305390.906250      3.0
# 3      100001.0       Kigali City    Urban       Q4  305390.906250      3.0
# 4      100001.0       Kigali City    Urban       Q4  305390.906250      3.0
# ...         ...               ...      ...      ...            ...      ...
# 66076  114419.0  Eastern Province    Rural       Q1   96416.578125      1.0
# 66077  114419.0  Eastern Province    Rural       Q1   96416.578125      1.0
# 66078  114420.0  Eastern Province    Rural       Q5  344908.468750      3.0
# 66079  114420.0  Eastern Province    Rural       Q5  344908.468750      3.0
# 66080  114420.0  Eastern Province    Rural       Q5  344908.468750      3.0
#
# ...

# %%
df.describe().T
# Out:
#                count           mean            std           min  \
# hhid         66081.0  107236.824307    4172.876037  100001.00000
# Consumption  66081.0  294923.562500  481185.000000    7338.55127
# poverty      66081.0       2.447965       0.755181       1.00000
#
#                        25%          50%          75%         max
# hhid         103618.000000  107308.0000  110856.0000    114420.0
# Consumption  125860.304688  187120.5625  297386.9375  12809880.0
# poverty           2.000000       3.0000       3.0000         3.0

# %%
df['Consumption'].describe()
# Out:
# count    6.608100e+04
# mean     2.949236e+05
# std      4.811850e+05
# min      7.338551e+03
# 25%      1.258603e+05
# 50%      1.871206e+05
# 75%      2.973869e+05
# max      1.280988e+07
# Name: Consumption, dtype: float64

# %%
df['poverty'].unique()  #To check the categories of the categorical variable
# Out:
# array([3., 1., 2.])

# %%
# Looking for missing values
df.isnull().sum()
# Out:
# hhid                  0
# province              0
# ur2_2012              0
# quintile              0
# Consumption           0
# poverty               0
# Gender                0
# Relationship_HHead    0
# Age                   0
# dtype: int64

# %%
#Examining the outliers
sns.histplot(df['Consumption'])
# Out:
# <Axes: xlabel='Consumption', ylabel='Count'>

# %%
#Examining the outliers
sns.boxplot(df['Consumption'])
# Out:
# <Axes: >

# %%
#One way table when the variable is categorical
pd.crosstab(index=df['Gender'], columns='Frequence')
# Out:
# col_0   Frequence
# Gender
# Male        31544
# Female      34537

# %%
#in terms of percentages
v=pd.crosstab(index=df['Gender'], columns='Frequence')
(v/v.sum()*100).round(2)
# Out:
# col_0   Frequence
# Gender
# Male        47.74
# Female      52.26

# %%
#two way table
b=pd.crosstab(df['province'],df['Gender'],margins=True,margins_name='Total')
(b/b.T['Total']*100).round(2)
# Out:
# Gender               Male  Female   Total
# province
# Kigali City          9.54    9.11    9.32
# Southern Province   25.88   26.19   26.05
# Western Province    23.93   24.35   24.15
# Northern Province   16.77   16.74   16.75
# Eastern Province    23.88   23.60   23.73
# Total              100.00  100.00  100.00

# %%
#three way tables

# %%
# Poverty status by gender and province
pd.crosstab([df.province,df.Gender],df.poverty)
# Out:
# poverty                    1.0   2.0   3.0
# province          Gender
# Kigali City       Male     232   301  2475
#                   Female   282   342  2524
# Southern Province Male    1010  2044  5111
#                   Female  1177  2320  5549
# Western Province  Male    1537  1770  4241
#                   Female  1814  2010  4587
# Northern Province Male    1081  1311  2898
#                   Female  1135  1543  3103
# Eastern Province  Male    1141  1665  4727
#                   Female  1263  1829  5059

# %%
tab=pd.crosstab([df.province,df.Gender],df.poverty,margins=True,margins_name='Total')
(tab.div(tab['Total'],axis=0)*100).round(2)
# Out:
# poverty                     1.0    2.0    3.0  Total
# province          Gender
# Kigali City       Male     7.71  10.01  82.28  100.0
#                   Female   8.96  10.86  80.18  100.0
# Southern Province Male    12.37  25.03  62.60  100.0
#                   Female  13.01  25.65  61.34  100.0
# Western Province  Male    20.36  23.45  56.19  100.0
#                   Female  21.57  23.90  54.54  100.0
# Northern Province Male    20.43  24.78  54.78  100.0
#                   Female  19.63  26.69  53.68  100.0
# Eastern Province  Male    15.15  22.10  62.75  100.0
#                   Female  15.50  22.44  62.07  100.0
# Total                     16.15  22.90  60.95  100.0

# %%
dg.groupby(['province',])

# %%
#average consumption
pd.pivot_table(data=df, index=['Gender'], values=['Consumption'])

# %% [markdown]
# ### Selecting / filtering the variables / rows in the dataframe

# %%
autop=auto.copy()

# %%
autop.head(1)
# Out:
#        hhid     province    district ur2012 ur2_2012       region     weight  \
# 0  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
#
#                                              hhtype  s0q19m  s0q19y  \
# 0  Replaced different household (dependent code 95)    11.0    13.0
#
#        pop_wt    clust      rwanda surveyh quintile  poverty   Consumption  \
# 0  214.379379  10001.0  All Rwanda   Panel       Q4      3.0  305390.90625
#
#           pid    s1q1                 s1q2 s1q3y  s1q3m       s1q4     s1q5  \
# 0  10000101.0  Female  Household head (HH)  33.0    NaN  Separated  Kamonyi
#
#        s1q6 s1q7 s1q8 s1q9 s1q10 s1q11 s1q12 s1q13 s1q14 s1q15        s2q1  \
# 0  Rwandese   No  NaN  NaN   NaN   Yes   NaN   NaN   NaN   Yes  10000101.0
#
#   s2q2 s2q3y s2q3m     s2q4         s2q5  s2q6        s2q7   s2q8        s3q1  \
# 0   No  18.0   0.0  Kamonyi  Countryside  15.0  Employment  Alone  10000101.0
#
# ...

# %%
# selecting the columns(variables) from hhid to region
autop.loc[:,'hhid':'region'].head(6)
# Out:
#        hhid     province    district ur2012 ur2_2012       region
# 0  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City
# 1  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City
# 2  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City
# 3  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City
# 4  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City
# 5  100002.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City

# %%
# selecting the columns(variables) ur2_2012 and region
autop.loc[:,['ur2_2012','region']]
# Out:
#       ur2_2012         region
# 0        Urban    Kigali City
# 1        Urban    Kigali City
# 2        Urban    Kigali City
# 3        Urban    Kigali City
# 4        Urban    Kigali City
# ...        ...            ...
# 66076    Rural  Rural Eastern
# 66077    Rural  Rural Eastern
# 66078    Rural  Rural Eastern
# 66079    Rural  Rural Eastern
# 66080    Rural  Rural Eastern
#
# [66081 rows x 2 columns]

# %%
#Selecting/filtering the rows in a datafrme
autop.loc[[2,3,4],:]
# Out:
#        hhid     province    district ur2012 ur2_2012       region     weight  \
# 2  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 3  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 4  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
#
#                                              hhtype  s0q19m  s0q19y  \
# 2  Replaced different household (dependent code 95)    11.0    13.0
# 3  Replaced different household (dependent code 95)    11.0    13.0
# 4  Replaced different household (dependent code 95)    11.0    13.0
#
#        pop_wt    clust      rwanda surveyh quintile  poverty   Consumption  \
# 2  214.379379  10001.0  All Rwanda   Panel       Q4      3.0  305390.90625
# 3  214.379379  10001.0  All Rwanda   Panel       Q4      3.0  305390.90625
# 4  214.379379  10001.0  All Rwanda   Panel       Q4      3.0  305390.90625
#
#           pid    s1q1                     s1q2 s1q3y  s1q3m    s1q4  \
# ...

# %%
#Selecting the rows from 2 to the end
autop.loc[2:]
# Out:
#            hhid          province    district ur2012 ur2_2012         region  \
# 2      100001.0       Kigali City  Nyarugenge  Urban    Urban    Kigali City
# 3      100001.0       Kigali City  Nyarugenge  Urban    Urban    Kigali City
# 4      100001.0       Kigali City  Nyarugenge  Urban    Urban    Kigali City
# 5      100002.0       Kigali City  Nyarugenge  Urban    Urban    Kigali City
# 6      100002.0       Kigali City  Nyarugenge  Urban    Urban    Kigali City
# ...         ...               ...         ...    ...      ...            ...
# 66076  114419.0  Eastern Province    Bugesera  Rural    Rural  Rural Eastern
# 66077  114419.0  Eastern Province    Bugesera  Rural    Rural  Rural Eastern
# 66078  114420.0  Eastern Province    Bugesera  Rural    Rural  Rural Eastern
# 66079  114420.0  Eastern Province    Bugesera  Rural    Rural  Rural Eastern
# 66080  114420.0  Eastern Province    Bugesera  Rural    Rural  Rural Eastern
#
# ...

# %%
# Selecting both columns and rows
autop.loc[3:10,'region':'quintile']
# Out:
#          region     weight                                            hhtype  \
# 3   Kigali City  71.459792  Replaced different household (dependent code 95)
# 4   Kigali City  71.459792  Replaced different household (dependent code 95)
# 5   Kigali City  71.459792  Replaced different household (dependent code 95)
# 6   Kigali City  71.459792  Replaced different household (dependent code 95)
# 7   Kigali City  71.459792  Replaced different household (dependent code 95)
# 8   Kigali City  71.459792      Panel head of households in the same cluster
# 9   Kigali City  71.459792      Panel head of households in the same cluster
# 10  Kigali City  71.459792      Panel head of households in the same cluster
#
#     s0q19m  s0q19y      pop_wt    clust      rwanda surveyh quintile
# 3     11.0    13.0  214.379379  10001.0  All Rwanda   Panel       Q4
# 4     11.0    13.0  214.379379  10001.0  All Rwanda   Panel       Q4
# 5     11.0    13.0  513.081299  10001.0  All Rwanda   Panel       Q5
# ...

# %%
autop.loc[[3,10,17,45,67],'region':'quintile']
# Out:
#          region      weight                                            hhtype  \
# 3   Kigali City   71.459792  Replaced different household (dependent code 95)
# 10  Kigali City   71.459792      Panel head of households in the same cluster
# 17  Kigali City   71.459792  Replaced different household (dependent code 95)
# 45  Kigali City  120.594509  Replaced different household (dependent code 95)
# 67  Kigali City  120.594509      Panel head of households in the same cluster
#
#     s0q19m  s0q19y      pop_wt    clust      rwanda surveyh quintile
# 3     11.0    13.0  214.379379  10001.0  All Rwanda   Panel       Q4
# 10    11.0    13.0  237.246506  10001.0  All Rwanda   Panel       Q5
# 17    11.0    13.0  200.802017  10001.0  All Rwanda   Panel       Q4
# 45    11.0    13.0  493.231537  10002.0  All Rwanda   Panel       Q5
# 67    11.0    13.0  601.408020  10002.0  All Rwanda   Panel       Q5

# %%
autop.loc[autop['s1q1']=='Male'].head(6)
# Out:
#        hhid     province    district ur2012 ur2_2012       region     weight  \
# 1  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 2  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 4  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 5  100002.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 6  100002.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 7  100002.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
#
#                                              hhtype  s0q19m  s0q19y  \
# 1  Replaced different household (dependent code 95)    11.0    13.0
# 2  Replaced different household (dependent code 95)    11.0    13.0
# 4  Replaced different household (dependent code 95)    11.0    13.0
# 5  Replaced different household (dependent code 95)    11.0    13.0
# 6  Replaced different household (dependent code 95)    11.0    13.0
# ...

# %%
autop.loc[autop['s1q1']=='Male'].shape[0]
# Out:
# 31544

# %% [markdown]
# ### select the number of rows where the consumption is greater or equal to 200,000

# %%
autop.loc[autop['Consumption']>=200000].shape[0]
# Out:
# 30109

# %%
# Selecting the dataframe where consumption is greater or equal to 300,000 and sex is Female
autop[(autop['Consumption']>=300000)&(autop['s1q1']=='Male')].shape[0]
# Out:
# 7997

# %%
autop[(autop['Consumption']>=300000)&(autop['s1q1']=='Male')&(autop['province']=='Kigali City')].shape[0]
# Out:
# 1702

# %%
autop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66081 entries, 0 to 66080
# Columns: 127 entries, hhid to s6fq12
# dtypes: category(113), float32(1), float64(12), object(1)
# memory usage: 17.1+ MB

# %%
#Filter the dataframe for females living in Southern Province
autop[(autop['s1q1']=='Female')&((autop['province']=='Southern Province')|(autop['province']=='Kigali City'))]
# Out:
#            hhid           province    district ur2012 ur2_2012       region  \
# 0      100001.0        Kigali City  Nyarugenge  Urban    Urban  Kigali City
# 3      100001.0        Kigali City  Nyarugenge  Urban    Urban  Kigali City
# 9      100003.0        Kigali City  Nyarugenge  Urban    Urban  Kigali City
# 10     100003.0        Kigali City  Nyarugenge  Urban    Urban  Kigali City
# 12     100003.0        Kigali City  Nyarugenge  Urban    Urban  Kigali City
# ...         ...                ...         ...    ...      ...          ...
# 29039  106439.0  Southern Province     Kamonyi  Urban    Urban  Other Urban
# 29040  106439.0  Southern Province     Kamonyi  Urban    Urban  Other Urban
# 29041  106439.0  Southern Province     Kamonyi  Urban    Urban  Other Urban
# 29043  106440.0  Southern Province     Kamonyi  Urban    Urban  Other Urban
# 29044  106440.0  Southern Province     Kamonyi  Urban    Urban  Other Urban
#
# ...

# %%
#Number of females living in Southern Province
autop.loc[(autop['s1q1']=='Female')&(autop['province']=='Southern Province')].shape[0]
# Out:
# 9046

# %%
autop['province'].unique()
# Out:
# ['Kigali City', 'Southern Province', 'Western Province', 'Northern Province', 'Eastern Province']
# Categories (5, object): ['Kigali City' < 'Southern Province' < 'Western Province' < 'Northern Province' < 'Eastern Province']

# %%
tab=pd.crosstab(index=autop['province'], columns='counts')

# %%
x=(tab/tab.sum()*100).round(2)
x
# Out:
# col_0              counts
# province
# Kigali City          9.32
# Southern Province   26.05
# Western Province    24.15
# Northern Province   16.75
# Eastern Province    23.73

# %%
ax=x.plot(kind='bar', figsize=(10,2))
plt.title('Just a bargraph', fontweight='bold')
plt.ylabel('percent')

for container in ax.containers:
    ax.bar_label(container)

# %%
#using see born library
sns.countplot(x='province',data=autop, palette='rocket')
plt.title('Province Distribution', fontweight='bold')
plt.rcParams['figure.figsize']=(10,5)  #adjasting the size
plt.xticks(rotation=40) #to adjust the x labels
plt.ylim([0,19000])

for container in ax.containers:
    ax.bar_label(container)
    plt.show()

# %%
tab=pd.crosstab(df['province'],df['Gender'])
az=(tab/tab.sum()*100).round(1)
az
# Out:
# Gender             Male  Female
# province
# Kigali City         9.5     9.1
# Southern Province  25.9    26.2
# Western Province   23.9    24.4
# Northern Province  16.8    16.7
# Eastern Province   23.9    23.6

# %%
#
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 # We need the total percentages to sum to 100 percent in each province
# ----> 2 y['Total']=y['Male']+y['Female']
#       4 y['Male_pct']=(y['Male'] / y['Total'])*100
#       5 y['Female_pct']=(y['Female'] / y['Total'])*100
#
# NameError: name 'y' is not defined
