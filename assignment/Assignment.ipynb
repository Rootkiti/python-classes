# %%
import pandas as pd

# %%
df = pd.read_stata("EICV5.dta")
pd.set_option('display.max_columns', None) 
df.head()
# Out:
#        hhid     province    district ur2012 ur2_2012       region     weight  \
# 0  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 1  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 2  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 3  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
# 4  100001.0  Kigali City  Nyarugenge  Urban    Urban  Kigali City  71.459792
#
#                                              hhtype  s0q19m  s0q19y  \
# 0  Replaced different household (dependent code 95)    11.0    13.0
# 1  Replaced different household (dependent code 95)    11.0    13.0
# 2  Replaced different household (dependent code 95)    11.0    13.0
# 3  Replaced different household (dependent code 95)    11.0    13.0
# 4  Replaced different household (dependent code 95)    11.0    13.0
#
#        pop_wt    clust      rwanda surveyh quintile  poverty   Consumption  \
# ...

# %%
"""

hhid	double	%10.0g		Household Identifier_in cross section
province	double	%10.0g	province	Province
district	double	%10.0g	district	District (also stratum CS; panel)
ur2012	double	%10.0g	ur2012	Urban/Rural 2012 (4 categories)
Urban_Rural	double	%10.0g	ur2_2012	Urban/Rural 2012 (2 categories)
region	double	%10.0g	region	Region
weight	double	%10.0g		Household Sampling weight_CS
hhtype	double	%10.0g	hhtype	Type of household according to the sample
s0q19m	double	%10.0g		Month of interview
s0q19y	double	%10.0g		Year of interview
pop_wt	double	%10.0g		Population Weight
clust	double	%10.0g		Cluster
rwanda	double	%10.0g	rwanda	All Rwanda
surveyh	double	%10.0g	surveyh	EICV4 survey sample
quintile	double	%10.0g	quintile	QUINTILE
poverty	double	%10.0g		POVERTY
Consumption	float	%9.0g		aggregate consumption/ae in Jan14 Prices
pid	double	%10.0g		Personal Uniq Identifier Annonymized
Gender	double	%10.0g	s1q1	Sex
Relationship_~D	double	%10.0g	s1q2	Relation with the head of household
Age	double	%10.0g	s1q3y	Age (Years)
s1q3m	double	%10.0g		Age (Months)
Marital_Status	double	%10.0g	s1q4	Marital status
Place_Birth	double	%10.0g	s1q5	Place of birth
s1q6	double	%10.0g	s1q6	Nationality
s1q7	double	%10.0g	s1q7	Absent in the last 12 months
s1q8	double	%10.0g	s1q8	Length of absence in last 12 months
s1q9	double	%10.0g	s1q9	Reason for absence
s1q10	double	%10.0g	s1q10	Lived in another HH during absence
s1q11	double	%10.0g	s1q11	Will be resident during enumeration period
s1q12	double	%10.0g	s1q12	Reason for absence
s1q13	double	%10.0g	s1q13	Father still alive
s1q14	double	%10.0g	s1q14	Mother still alive
s1q15	double	%10.0g	s1q15	HH membership
s2q1	double	%10.0g		pid of respondent
s2q2	double	%10.0g	s2q2	Always lived in the district
s2q3y	double	%10.0g	s2q3y	Time since last move (years)
s2q3m	double	%10.0g	s2q3m	Time since last move (months)
s2q4	double	%10.0g	s2q4	District or foreign country lived prior to arrival
s2q5	double	%10.0g	s2q5	Kind of place lived prior to arrival
s2q6	double	%10.0g	s2q6	Duration of stay in the previous location (years)
s2q7	double	%10.0g	s2q7	Primary reason for moving
s2q8	double	%10.0g	s2q8	Moved alone or with other HH members
s3q1	double	%10.0g		pid of respondent
s3q2	double	%10.0g	s3q2	Suffers from a major disability
Insurance	double	%10.0g	s3q3	Main health insurance
s3q4	double	%10.0g	s3q4	Suffered from health problem in the last 4 weeks
s3q5	double	%10.0g	s3q5	Nature of the health problem
s3q6	double	%10.0g	s3q6	Medical consultation over the last 4 weeks
s3q7	double	%10.0g	s3q7	Reason for medical consultation
s4aq1	double	%10.0g	s4aq1	Ever been to school
s4aq2	double	%10.0g	s4aq2	Highest class successfully completed
s4aq3	double	%10.0g	s4aq3	Highest diploma obtained
s4aq4a	str36	%36s		Field of education of diploma
s4aq4b	double	%10.0g	s4aq4b	ISCED code
s4aq5	double	%10.0g	s4aq5	Last higher institution attended
s4aq6a	double	%10.0g	s4aq6a	Class attended during school year 2012
s4aq6b	double	%10.0g	s4aq6b	Class attended during school year 2013
s4aq7	double	%10.0g	s4aq7	Attended school in previous 12 months
s4aq8	double	%10.0g	s4aq8	Type of school attended in previous 12 months
s4aq9	double	%10.0g	s4aq9	Problem experienced at school
s4aq10	double	%10.0g	s4aq10	School has separate toilet facilities for boys and girls
s4aq11a	double	%10.0g	s4aq11a	Registration and school fees
s4aq11b	double	%10.0g	s4aq11b	Parent contributions
s4aq11c	double	%10.0g	s4aq11c	School uniforms expenses
s4aq11d	double	%10.0g	s4aq11d	Books and school supplies expenses
s4aq11e	double	%10.0g	s4aq11e	Transport to and from school expenses
s4aq11f	double	%10.0g	s4aq11f	Room and board (or board only) expenses
s4aq11g	double	%10.0g	s4aq11g	Other school expenses
s4aq11h	double	%10.0g	s4aq11h	Total education expenses (non-distributed option)
s4aq12	double	%10.0g	s4aq12	Who paid school expenses over last 12 months
s4aq13	double	%10.0g	s4aq13	Missed any day at school in the last 7 days?
s4aq14	double	%10.0g	s4aq14	Number of school days missed in the last 7 days
s4aq15	double	%10.0g	s4aq15	Cause of not attending school
s4aq16	double	%10.0g	s4aq16	Year left school
s4aq17	double	%10.0g	s4aq17	Reason for leaving school
s4bq1	double	%10.0g	s4bq1	Post-school/vocational training in last 12 months
s4bq2	double	%10.0g	s4bq2	Expense of post-school/vocational training
s4bq3	double	%10.0g	s4bq3	Can read a letter or a simple note
s4bq4	double	%10.0g	s4bq4	Can write a letter or a simple note
s4bq5	double	%10.0g	s4bq5	Can perform a written calculation
s4bq6	double	%10.0g	s4bq6	Feels confident about using a computer
s4bq7	double	%10.0g	s4bq7	Attended literacy course
s4bq8	double	%10.0g	s4bq8	Has a mobile telephone
s6aq2	double	%10.0g	s6aq2	Work on own/HH farm (last 12 months)
s6aq3	double	%10.0g	s6aq3	Agricultural work for salary, wages, in-kind (last 12 months)
s6aq4	double	%10.0g	s6aq4	Non-farm work for salary or wages (last 12 months)
s6aq5	double	%10.0g	s6aq5	Non-farm business for cash/profit (last 12 months)
s6aq6	double	%10.0g	s6aq6	Worked in HH member non-farm business for no payment (last 12	months)
s6aq7a	double	%10.0g	s6aq7a	Number of jobs over past 12 months
s6aq7b	double	%10.0g	s6aq7b	Number of jobs over past 7 days
s6aq8	double	%10.0g	s6aq8	Main reason for not working (last 12 months)
s6eq1	double	%10.0g	s6eq1	Worked for one hour in the last 7 days in S6A activities
s6eq2	double	%10.0g	s6eq2	Usually works but absent last week
s6eq3	double	%10.0g	s6eq3	Reason for absence from work; last 7 days
s6eq4	double	%10.0g	s6eq4	Usual hours worked in job; 7 day period
s6eq5	double	%10.0g	s6eq5	Worked in other activities in the last 7 days
s6eq6	double	%10.0g	s6eq6	Reason not working in the last 7 days
s6eq7	double	%10.0g	s6eq7	Able to start work if the opportunity existed
s6eq8	double	%10.0g	s6eq8	Seeking a job during the last 4 weeks
s6eq9	double	%10.0g	s6eq9	Steps taken to seek work during last 4 weeks
s6eq10	double	%10.0g	s6eq10	Desire to work at the present
s6eq11	double	%10.0g	s6eq11	Reason not seeking a job in last 4 weeks
s6eq12a	double	%10.0g	s6eq12a	Period looking for a job (year)
s6eq12b	double	%10.0g	s6eq12b	Period looking for a job (month)
s6eq13	double	%10.0g	s6eq13	Ever worked before
s6eq14	double	%10.0g	s6eq14	Reason stopped working in last job
s6eq15	double	%10.0g	s6eq15	Employment status last job
s6eq16	double	%10.0g	s6eq16	Kind of establishments in previous employment
s6eq17	double	%10.0g	s6eq17	Wanted additional work
s6eq18	double	%10.0g	s6eq18	Number of additional hours preferred to work in last 7 days
s6eq19	double	%10.0g	s6eq19	Desire to change current job
s6eq20	double	%10.0g	s6eq20	Reason wants to change current job
s6eq21	double	%10.0g	s6eq21	Current main job/activity match training
s6eq0a	double	%10.0g		ID number
s6fq1	double	%10.0g	s6fq1	Fetched water last 7 days
s6fq2	double	%10.0g	s6fq2	Number of hours fetching water last 7 days
s6fq3	double	%10.0g	s6fq3	Foraged for firewood last 7 days
s6fq4	double	%10.0g	s6fq4	Number of hours foraging for wood last 7 days
s6fq5	double	%10.0g	s6fq5	Searched fodder last 7 days
s6fq6	double	%10.0g	s6fq6	Number of hours searching fodder last 7 days
s6fq7	double	%10.0g	s6fq7	Went to the market last 7 days
s6fq8	double	%10.0g	s6fq8	Number of hours going to market last 7 days
s6fq9	double	%10.0g	s6fq9	Cooked for household last 7 days
s6fq10	double	%10.0g	s6fq10	Number of hours cooking last 7 days
s6fq11	double	%10.0g	s6fq11	Did other household chores last 7 days
s6fq12	double	%10.0g	s6fq12	Number of hours spent on other household chores last 7 days

"""
# Out:
# '\n\nhhid\tdouble\t%10.0g\t\tHousehold Identifier_in cross section\nprovince\tdouble\t%10.0g\tprovince\tProvince\ndistrict\tdouble\t%10.0g\tdistrict\tDistrict (also stratum CS; panel)\nur2012\tdouble\t%10.0g\tur2012\tUrban/Rural 2012 (4 categories)\nUrban_Rural\tdouble\t%10.0g\tur2_2012\tUrban/Rural 2012 (2 categories)\nregion\tdouble\t%10.0g\tregion\tRegion\nweight\tdouble\t%10.0g\t\tHousehold Sampling weight_CS\nhhtype\tdouble\t%10.0g\thhtype\tType of household according to the sample\ns0q19m\tdouble\t%10.0g\t\tMonth of interview\ns0q19y\tdouble\t%10.0g\t\tYear of interview\npop_wt\tdouble\t%10.0g\t\tPopulation Weight\nclust\tdouble\t%10.0g\t\tCluster\nrwanda\tdouble\t%10.0g\trwanda\tAll Rwanda\nsurveyh\tdouble\t%10.0g\tsurveyh\tEICV4 survey sample\nquintile\tdouble\t%10.0g\tquintile\tQUINTILE\npoverty\tdouble\t%10.0g\t\tPOVERTY\nConsumption\tfloat\t%9.0g\t\taggregate consumption/ae in Jan14 Prices\npid\tdouble\t%10.0g\t\tPersonal Uniq Identifier Annonymized\nGender\tdouble\t%10.0g
# ...

# %%
df.shape
# Out:
# (66081, 127)

# %%
df['pid'].duplicated().sum()
# Out:
# 0

# %%
nulls = pd.DataFrame(df.isnull().sum())
nulls
# Out:
#               0
# hhid          0
# province      0
# district      0
# ur2012        0
# ur2_2012      0
# ...         ...
# s6fq8     48086
# s6fq9     11948
# s6fq10    38539
# s6fq11    11948
# s6fq12    34282
#
# [127 rows x 1 columns]

# %%
import pyreadstat as dhs

# %%
dhs_df, meta = dhs.read_sav("DHS2020/RWPR81FL.SAV")
dhs_df['SH17A']
# Out:
# 0        NaN
# 1        NaN
# 2        5.0
# 3        4.0
# 4        1.0
#         ...
# 55915    2.0
# 55916    4.0
# 55917    4.0
# 55918    2.0
# 55919    NaN
# Name: SH17A, Length: 55920, dtype: float64

# %%
meta.column_names_to_labels['SH17A']
# Out:
# 'Level of education attended'

# %%
help(dhs.read_sav)
# Out:
# Help on cython_function_or_method in module pyreadstat.pyreadstat:
#
# read_sav(filename_path, metadataonly=False, dates_as_pandas_datetime=False, apply_value_formats=False, formats_as_category=True, formats_as_ordered_category=False, encoding=None, usecols=None, user_missing=False, disable_datetime_conversion=False, row_limit=0, row_offset=0, output_format=None, extra_datetime_formats=None, extra_date_formats=None)
#     Read a SPSS sav or zsav (compressed) files
#
#     Parameters
#     ----------
#         filename_path : str, bytes or Path-like object
#             path to the file. In Python 2.7 the string is assumed to be utf-8 encoded
#         metadataonly : bool, optional
#             by default False. IF true, no data will be read but only metadata, so that you can get all elements in the
#             metadata object. The data frame will be set with the correct column names but no data.
#         dates_as_pandas_datetime : bool, optional
# ...

# %% [markdown]
# 1. `HVO24` : region
# 2. `HV206` : electricity
# 3. `HV201` : water
# 4. `HV226` : cooking fuel type
# 5. `SH121G` : matress
#
# 6. `SH16` : attended school
# 7. `SH17A` : level of eduction
#
# consumption
# 8. `s4aq1`: ever been at school
# 9. `s4eq2` : level of eductation
# 10. `s6eq15`: employment status last job
# 11. `s6eq21` : level of eductation matches with the job
# 12. `region` : region
# 13. `Consumption`: consumption
# 14. `s1q1` : sex
# 15. `s1q3y` : ages
# 16. `s1q4` : martal stsus
# 17. `ur2_2012` : locality

# %%
filtered_df = dhs_df[dhs_df.apply(lambda row: row.astype(str).str.contains("work|employment", case=False).any(), axis=1)]

print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [HHID, HVIDX, HV000, HV001, HV002, HV003, HV004, HV005, HV006, HV007, HV008, HV008A, HV009, HV010, HV011, HV012, HV013, HV014, HV015, HV016, HV017, HV018, HV019, HV020, HV021, HV022, HV023, HV024, HV025, HV026, HV027, HV028, HV030, HV031, HV032, HV035, HV040, HV041, HV042, HV044, HV045A, HV045B, HV045C, HV046, HV801, HV802, HV803, HV804, HV807D, HV807M, HV807Y, HV807C, HV807A, HV201, HV202, HV201A, HV204, HV205, HV206, HV207, HV208, HV209, HV210, HV211, HV212, HV213, HV214, HV215, HV216, HV217, HV218, HV219, HV220, HV221, HV225, HV226, HV227, HV228, HV230A, HV230B, HV232, HV232B, HV232C, HV232D, HV232E, HV232Y, HV234, HV234A, HV235, HV236, HV237, HV237A, HV237B, HV237C, HV237D, HV237E, HV237F, HV237G, HV237H, HV237I, ...]
# Index: []
